# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "none"

from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

mobile_image = Image.open('../data/example_mobile_image.jpg')
catalogue_image = Image.open('../data/example_catalogue_image.jpg')

plt.figure(figsize=(20,10))

plt.subplot(1,2,1)
plt.imshow(mobile_image)

plt.subplot(1,2,2)
plt.imshow(catalogue_image)
